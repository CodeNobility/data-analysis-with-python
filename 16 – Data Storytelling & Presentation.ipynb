# %%
# STEP 1

# %% [markdown]
# Structure the Story (VERY IMPORTANT)
#
# Use this 5-part framework (memorize it):
#
# Business Problem
#
# Approach
#
# Key Findings
#
# Insights
#
# Recommendations

# %%
# STEP 2 SLIDE 1

# %% [markdown]
# Slide-by-Slide Outline (Professional)
# Slide 1: Business Objective
#
# “Analyze retail transaction data to understand revenue drivers, customer segments, and product performance.”

# %%
# SLIDE 2

# %% [markdown]
# Slide 2: Dataset Overview
#
# Transactions: X
#
# Time period: YYYY–YYYY
#
# Key fields: Date, Customer, Product, Revenue
#
# (Short. No code.)

# %%
# Slide 3

# %% [markdown]
# Sales Trend
#
# Chart: Line chart – Monthly revenue
#
# Narrative:
#
# Sales show clear month-to-month variation, indicating seasonality in customer purchasing behavior.

# %%
# SLIDE 4

# %% [markdown]
# Product Category Performance
#
# Chart: Bar chart – Revenue by category
#
# Narrative:
#
# Electronics is the top-performing category, contributing the largest share of total revenue.

# %%
# SLIDE 5

# %% [markdown]
# Customer Segmentation
#
# Charts:
#
# Revenue by Gender
#
# Revenue by Age Group
#
# Narrative:
#
# Adult and Young Adult customers generate the majority of revenue, with relatively balanced spending across genders.

# %%
# SLIDE 6

# %% [markdown]
# High-Value Customers
#
# Chart: Bar (Top 5 customers)
#
# Narrative:
#
# A small set of customers contributes a disproportionate share of revenue, highlighting opportunities for loyalty programs.

# %%
# SLIDE 7

# %% [markdown]
# Revenue Drivers
#
# Chart: Correlation table / scatter
#
# Narrative:
#
# Both quantity purchased and price per unit strongly influence total transaction value.

# %%
# SLIDE 8

# %% [markdown]
# Key Insights (Bullet-Only)
#
# Electronics dominates revenue
#
# Adult customers are the most valuable segment
#
# High-value customers drive significant revenue
#
# Sales show time-based patterns

# %%
# SLIDE 9

# %% [markdown]
# Recommendations (MOST IMPORTANT)
#
# Focus marketing on top product categories
#
# Create loyalty programs for high-value customers
#
# Design targeted campaigns for Adult & Young Adult segments
#
# Optimize pricing and bundles for higher transaction value

# %%
# Write one executive paragraph (5–6 lines):

# %% [markdown]
# Based on transaction analysis, Electronics contributes the highest revenue, while Adult customers form the most valuable segment. Revenue is strongly driven by quantity and pricing, suggesting opportunities in bundling and premium products. A small group of high-value customers presents a strong case for targeted loyalty initiatives.
